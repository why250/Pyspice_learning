# %% [markdown]
# # TL431 Simulation
#
# By Shuo Chen (chenshuo_at_chenshuo.com)
#
# Latest notebook: https://github.com/chenshuo/notes/blob/master/notebooks/TL431.ipynb
#
# Analysis and calculation notes: https://chenshuo.github.io/notes/tl431

# %%
# %matplotlib inline

from math import exp, log, log10
import numpy as np
from matplotlib import pyplot as plt

# %%
import os

# 1. 路径配置
bin_path = r'C:\Spice64\bin_dll'
share_path = r'C:\Spice64\share\ngspice'

if os.path.exists(bin_path):
    os.add_dll_directory(bin_path)
    os.environ['PATH'] = bin_path + os.pathsep + os.environ['PATH']
    os.environ['SPICE_LIB_DIR'] = share_path 
    print(f"✅ 环境路径已配置: {bin_path}")

# 2. 导入并修正验证逻辑
try:
    import ngspyce as ng
    print("🚀 ngspyce 导入成功！")
    
    # 修正点：ng.cmd() 返回的是 list
    v_info_list = ng.cmd("version -s") 
    # 将列表内容合并为一个字符串再打印
    v_info_str = "".join(v_info_list).strip()
    print(f"🔧 Ngspice 引擎版本: {v_info_str}")
    
except Exception as e:
    print(f"❌ 依然报错: {e}")
# Out:
# ✅ 环境路径已配置: C:\Spice64\bin_dll
# 🚀 ngspyce 导入成功！
# 🔧 Ngspice 引擎版本: ******** ngspice-34** Please get your ngspice manual from http://ngspice.sourceforge.net/docs.html** Please file your bug-reports at http://ngspice.sourceforge.net/bugrep.html** Creation Date: Jan 29 2021   16:38:37******

# %%
import matplotlib.pyplot as plt
import numpy as np

# 1. 定义电路：10V 50Hz 交流电，通过 1N4148 二极管给 1k 负载供电
netlist = """
* Half-Wave Rectifier
V1 ac_in 0 sin(0 10 50)
D1 ac_in load di_model
R1 load 0 1k
.model di_model d(is=1e-14)
.tran 100u 40m
.end
"""

ng.circ(netlist)
ng.cmd("run")

# 2. 获取数据
time = ng.vector('time')
v_in = ng.vector('ac_in')
v_load = ng.vector('load')

# 3. 绘图
plt.figure(figsize=(10, 5))
plt.plot(time * 1000, v_in, label='Input (AC)', color='lightgray', linestyle='--')
plt.plot(time * 1000, v_load, label='Output (Rectified)', linewidth=2)
plt.title("Diode Half-Wave Rectification")
plt.xlabel("Time (ms)")
plt.ylabel("Voltage (V)")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ERROR:ngspyce.sharedspice:Warning: v1: no DC value, transient time 0 value used

# %%
# NgSpice
import ngspyce as ng

# %%
# Circuitikz
# pip install git+https://github.com/mkrphys/ipython-tikzmagic.git

# %load_ext tikzmagic
# Out:
# The tikzmagic extension is already loaded. To reload it, use:
#   %reload_ext tikzmagic

# %%
def para(r1, r2):
    return (r1*r2) / (r1 + r2)

def print_op(print_base_current=True, print_emitter_current=False):
  op = ng.operating_point()
  for k in sorted(op.keys()):
    if k[0] == '@' or '#branch' in k:
        if '[is]' in k:
            continue
        if '[ib]' in k and not print_base_current:
            continue
        if '[ie]' in k and not print_emitter_current:
            continue

        print('%10s = %8.2f uA' % (k, 1e6*op[k][0]))
    else:
        print('%10s = %8.2f mV' % (k, 1e3*op[k][0]))

# %% [markdown]
# ![tl431c.png](attachment:98a8b05e-f0fe-4282-9306-8d7d6038eadd.png)

# %% [markdown]
# ## DC operating point

# %%
# %load_ext tikzmagic

# 如果你的 pdflatex 路径不在环境变量中，可能需要指定
# %config InlineBackend.figure_format = 'svg'
# Out:
# The tikzmagic extension is already loaded. To reload it, use:
#   %reload_ext tikzmagic

# %%
# %load_ext tikzmagic
# 配置 tikzmagic 默认使用 svg 格式和 pdf2svg 转换器
# %config TikzMagics.format = 'svg'
# Out:
# The tikzmagic extension is already loaded. To reload it, use:
#   %reload_ext tikzmagic

# %%
# %%tikz -p circuitikz -f svg -s 400,400
#
# \ctikzset{european resistors, american currents}
#
# \draw (0, 0) node [sground] {} node[left] {A}
#   to [zzD*, n=D, *-*] ++(0, 1.5) coordinate (K)
#   node [left] {K};
#
# \draw (D.center) to [short] ++(-1.2, 0)
#   coordinate (R)  node [left] {2.4954V}
#   to [R, l2={$R_\mathrm{b}$ and 1k}, bipoles/length=1.2cm] ++(0, 1.6)
#   coordinate (R2)
#   to [short, -*, i<={1.92uA}] (R2 -|D)
#   to [short, i={$I_\mathrm{KA}\approx10\mathrm{mA}$}]  (K);
#
# \draw (R2-|D) to [short, -o] ++(0.5, 0)
#   ++(-0.1, 0.2) node [right] {Vout = 2.4973V};
#
# \draw (R2 -|D) to [I, invert, l={10mA}] ++(0, 1.8) node [ocirc] {};

# %%
ng.circ('''
  I1 0 cathode 10m
  Rb cathode ref 1k

  Q1 cathode ref q1e NPN 1
  R4 q1e mid 3.28k
  R2 mid q2b 2.4k
  R3 mid q5b 7.2k
  Q2 q2b q2b 0 NPN 3
  Q3 q5b q2b r1 NPN 6
  R1 r1 0 800

  R7 cathode q7e 800
  Q7 q7b q7b q7e PNP
  Q4 q7b q1e q4e NPN 1
  R5 q4e q5c     4k
  Q5 q5c q5b 0   NPN 1

  R8 cathode q8e 800
  Q8 q9b q7b q8e PNP
  R6 q2b q6b 1k
  Q6 q9b q6b 0 NPN 1

  Q9 cathode q9b q9e NPN
  R9 q9e q10b 150
  Q10 cathode q10b 0 NPN 50
  R10 q10b 0 10k

  .options savecurrents
  .model NPN NPN(IS=1f BF=120 Cje=1p Cjc=2p VAF=80)
  .model PNP PNP(IS=10f BF=80 Cje=1p Cjc=2p VAF=80)
''')

print_op()
# Out:
# @i1[current] = 10000.00 uA
#   @q10[ib] =    77.46 uA
#   @q10[ic] =  9507.25 uA
#    @q1[ib] =     1.92 uA
#    @q1[ic] =   230.42 uA
#    @q2[ib] =     1.43 uA
#    @q2[ic] =   171.61 uA
#    @q3[ib] =     0.48 uA
#    @q3[ic] =    57.36 uA
#    @q4[ib] =     0.49 uA
#    @q4[ic] =    59.16 uA
#    @q5[ib] =     0.50 uA
#    @q5[ic] =    59.66 uA
#    @q6[ib] =     0.47 uA
#    @q6[ic] =    56.68 uA
#    @q7[ib] =     0.72 uA
#    @q7[ic] =    57.72 uA
#    @q8[ib] =     0.72 uA
#    @q8[ic] =    57.86 uA
#    @q9[ib] =     1.18 uA
#    @q9[ic] =   143.40 uA
#    @r10[i] =    67.12 uA
#     @r1[i] =    57.84 uA
#     @r2[i] =   173.99 uA
#     @r3[i] =    57.86 uA
#     @r4[i] =   231.84 uA
#     @r5[i] =    59.66 uA
#     @r6[i] =     0.47 uA
#     @r7[i] =    58.45 uA
#     @r8[i] =    58.58 uA
#     @r9[i] =   144.57 uA
#     @rb[i] =     1.92 uA
#    cathode =  2497.31 mV
#        mid =  1058.24 mV
#       q10b =   671.16 mV
#        q1e =  1818.68 mV
#        q2b =   640.67 mV
#        q4e =  1177.15 mV
#        q5b =   641.66 mV
#        q5c =   938.53 mV
#        q6b =   640.20 mV
#        q7b =  1869.20 mV
#        q7e =  2450.55 mV
#        q8e =  2450.45 mV
#        q9b =  1356.92 mV
#        q9e =   692.84 mV
#         r1 =    46.27 mV
#        ref =  2495.39 mV

# %% [markdown]
# ## Dynamic Impedance

# %%
ng.cmd('dc i1 1m 100m 1m')
Ika = ng.vector('i-sweep')
Vout = ng.vector('cathode')
plt.plot(Ika*1e3, Vout)
plt.xlabel('Ika (mA)')
plt.ylabel('Vka (V)')
plt.title('Dynamic Impedance of TL431')
print('Dynamic Impedance = %.2f Ohm' % ((max(Vout)-min(Vout))/(max(Ika) - min(Ika))))
# Out:
# Dynamic Impedance = 0.14 Ohm

# %% [markdown]
# ## DC Gain

# %%
# %%tikz -p circuitikz -f svg -s 500,400
# \ctikzset{european resistors, american currents, bipoles/length=1.2cm}
# \draw(0, 0) node [circ] {}
#   coordinate (REF)
#   to [R, l2_={$R_2$ and 8.25k}] ++(0, -1.8)
#   coordinate (G);
# \draw (REF) node [left] {Vref}
#     to [vR, l2={$R_1$ and {0 to 40k}}, l2 halign=r, mirror] ++(0, +1.8)
#     to [short, -*] ++(1.5, 0) coordinate (OUT)
#     to [zzD*,n=D,invert, mirror, -*, i>^={$I_\mathrm{KA}$}] (OUT|-G)
#     node [ground] {} -- (G);
# \draw (D.center) to [short, -*] (D.center-|REF);
# \draw (OUT) to [short, -*] ++(0, 0.8) coordinate (R)
#   to [I, invert, -o, l_={10mA}] ++(-2,0)
#   node [above] {Vcc};
# \draw (R) to [short, -o] ++(0.5, 0) node [above] {Vout};

# %%
ng.circ('''
  * V1 vcc 0 15V
  * Rb vcc cathode 232
  I1 0 cathode 10m
  Rx1 cathode ref 15k
  Rx2 ref 0 8.25k

  Q1 cathode ref q1e NPN 1
  R4 q1e mid 3.28k
  R2 mid q2b 2.4k
  R3 mid q5b 7.2k
  Q2 q2b q2b 0 NPN 3
  Q3 q5b q2b r1 NPN 6
  R1 r1 0 800

  R7 cathode q7e 800
  Q7 q7b q7b q7e PNP
  Q4 q7b q1e q4e NPN 1
  R5 q4e q5c     4k
  Q5 q5c q5b 0   NPN 1

  R8 cathode q8e 800
  Q8 q9b q7b q8e PNP
  R6 q2b q6b 1k
  Q6 q9b q6b 0 NPN 1

  Q9 cathode q9b q9e NPN
  R9 q9e q10b 150
  Q10 cathode q10b 0 NPN 50
  R10 q10b 0 10k

  .options savecurrents
  .model NPN NPN(IS=1f BF=120 Cje=1p Cjc=2p VAF=80)
  .model PNP PNP(IS=10f BF=80 Cje=1p Cjc=2p VAF=80)
''')

print_op(False)
# Out:
# @i1[current] = 10000.00 uA
#   @q10[ic] =  9214.03 uA
#    @q1[ic] =   229.97 uA
#    @q2[ic] =   171.17 uA
#    @q3[ic] =    57.31 uA
#    @q4[ic] =    57.70 uA
#    @q5[ic] =    58.15 uA
#    @q6[ic] =    56.53 uA
#    @q7[ic] =    56.31 uA
#    @q8[ic] =    57.60 uA
#    @q9[ic] =   136.94 uA
#    @r10[i] =    66.89 uA
#     @r1[i] =    57.79 uA
#     @r2[i] =   173.54 uA
#     @r3[i] =    57.79 uA
#     @r4[i] =   231.33 uA
#     @r5[i] =    58.15 uA
#     @r6[i] =     0.47 uA
#     @r7[i] =    57.02 uA
#     @r8[i] =    58.28 uA
#     @r9[i] =   138.01 uA
#    @rx1[i] =   303.76 uA
#    @rx2[i] =   301.95 uA
#    cathode =  7047.56 mV
#        mid =  1057.10 mV
#       q10b =   668.94 mV
#        q1e =  1815.87 mV
#        q2b =   640.60 mV
#        q4e =  1176.42 mV
#        q5b =   641.00 mV
#        q5c =   943.82 mV
#        q6b =   640.14 mV
#        q7b =  6421.23 mV
#        q7e =  7001.94 mV
#        q8e =  7000.94 mV
#        q9b =  1351.12 mV
#        q9e =   689.65 mV
#         r1 =    46.23 mV
#        ref =  2491.09 mV

# %%
ng.cmd('dc rx1 10 40k 10')
r1 = ng.vector('res-sweep') / 1e3
out = ng.vector('cathode')
ref = ng.vector('ref')
fig,ax = plt.subplots()
plt.plot(r1, out)
plt.xlabel('R1 (kΩ)')
plt.ylabel('Vout')
ax2 = ax.twinx()
plt.plot(r1, ref, 'red')
plt.ylabel('Vref')
# Out:
# Text(0, 0.5, 'Vref')

# %%
Irx1 = ng.vector('@rx1[i]')
Irx2 = ng.vector('@rx2[i]')
plt.plot(r1, Irx1)
plt.plot(r1, Irx2)

# %%
plt.plot(out, ref)
plt.xlabel('Vout')
plt.ylabel('Vref')
deltaVout = max(out) - min(out)
deltaVref = ref[-1] - ref[0]
print('Delta Vref / Delta Vout = %.2f mV' % (1e3*(deltaVref / deltaVout)))
gain = deltaVout / deltaVref
dB = 20*log10(-gain)
print('DC gain %.1f, %.1f dB' % (gain, dB))
# Out:
# Delta Vref / Delta Vout = -0.90 mV
# DC gain -1116.0, 61.0 dB

# %% [markdown]
# ## Feedback loop

# %%
# %%tikz -p circuitikz -f svg -s 400,400
#
# \ctikzset{european resistors, american currents}
#
# \draw (0, 0) node [sground] {} node[right] {A}
#   to [zzD*, n=D, *-*] ++(0, 1.5) coordinate (K)
#   node [right] {K}
#   to [R, l2_={$R_\mathrm{b}$ and 1k}, bipoles/length=1.2cm] ++(0, 1.6)
#   node [vcc] {5V};
#
# \draw (D.center) to [short] ++(-0.8, 0)
#   coordinate (R) node [below] {2.495V\quad\ }
#   to [short, i<={$\sim$2uA}] (R |-K) -- (K);
# %  coordinate (R2)
#
# %  to [short, i={$I_\mathrm{KA}\approx10\mathrm{mA}$}]  (K);
#
# %\draw (R2-|D) to [short, -o] ++(0.5, 0)
# %  ++(-0.1, 0.2) node [right] {Vout = 2.4973V};
#
# %\draw (R2 -|D) to [I, invert, l={10mA}] ++(0, 1.8) node [ocirc] {};

# %%
ng.circ('''
  V1 vcc 0 5V
  Rb vcc cathode 1k
  Rr cathode ref 1m

  Q1 cathode ref q1e NPN 1
  R4 q1e mid 3.28k
  R2 mid q2b 2.4k
  R3 mid q5b 7.2k
  Q2 q2b q2b 0 NPN 3
  Q3 q5b q2b r1 NPN 6
  R1 r1 0 800

  R7 cathode q7e 800
  Q7 q7b q7b q7e PNP
  Q4 q7b q1e q4e NPN 1
  R5 q4e q5c     4k
  Q5 q5c q5b 0   NPN 1

  R8 cathode q8e 800
  Q8 q9b q7b q8e PNP
  R6 q2b q6b 1k
  Q6 q9b q6b 0 NPN 1

  Q9 cathode q9b q9e NPN
  R9 q9e q10b 150
  Q10 cathode q10b 0 NPN 50
  R10 q10b 0 10k

  .options savecurrents
  .model NPN NPN(IS=1f BF=120 Cje=1p Cjc=2p VAF=80)
  .model PNP PNP(IS=10f BF=80 Cje=1p Cjc=2p VAF=80)
''')

op5V = ng.operating_point()
ng.cmd('alter v1 10.7926V')
op10V = ng.operating_point()
print('Ref changed %.3f mV' % (1e3 * (op10V['ref'][0] - op5V['ref'][0])))
# Out:
# Ref changed 1.000 mV

# %%
def diff_op(lhs, rhs):
  for k in sorted(lhs.keys()):
    old = lhs[k][0]
    new = rhs[k][0]
    if k[0] == '@' or '#' in k:
        if np.abs(new - old) < 1e-9:
            continue
        print('%15s %10.3f uA, %10.3f uA, delta %10.3f uA' %
              (k, old * 1e6, new * 1e6, (new - old) * 1e6))
    else:
        print('%15s %10.3f mV, %10.3f mV, delta %10.3f mV' %
              (k, old * 1e3, new * 1e3, (new - old)* 1e3))

# %%
diff_op(op5V, op10V)
# Out:
#        @q10[ib]     16.928 uA,     63.704 uA, delta     46.776 uA
#        @q10[ic]   2078.597 uA,   7819.199 uA, delta   5740.602 uA
#        @q10[ie]  -2095.525 uA,  -7882.903 uA, delta  -5787.378 uA
#         @q1[ib]      1.918 uA,      1.920 uA, delta      0.002 uA
#         @q1[ic]    230.187 uA,    230.368 uA, delta      0.181 uA
#         @q1[ie]   -232.105 uA,   -232.287 uA, delta     -0.182 uA
#         @q2[ib]      1.428 uA,      1.430 uA, delta      0.001 uA
#         @q2[ic]    171.415 uA,    171.568 uA, delta      0.153 uA
#         @q2[ie]   -172.843 uA,   -172.998 uA, delta     -0.155 uA
#         @q3[ic]     57.339 uA,     57.357 uA, delta      0.018 uA
#         @q3[ie]    -57.817 uA,    -57.835 uA, delta     -0.019 uA
#         @q4[ib]      0.487 uA,      0.492 uA, delta      0.004 uA
#         @q4[ic]     58.498 uA,     59.022 uA, delta      0.524 uA
#         @q4[ie]    -58.986 uA,    -59.514 uA, delta     -0.528 uA
#         @q5[ib]      0.490 uA,      0.494 uA, delta      0.004 uA
#         @q5[ic]     58.986 uA,     59.514 uA, delta      0.528 uA
#         @q5[ie]    -59.475 uA,    -60.008 uA, delta     -0.533 uA
#         @q6[ic]     56.572 uA,     56.660 uA, delta      0.088 uA
#         @q6[ie]    -57.040 uA,    -57.128 uA, delta     -0.088 uA
#         @q7[ib]      0.713 uA,      0.720 uA, delta      0.006 uA
#         @q7[ic]     57.075 uA,     57.586 uA, delta      0.511 uA
#         @q7[ie]    -57.788 uA,    -58.306 uA, delta     -0.517 uA
#         @q8[ib]      0.710 uA,      0.717 uA, delta      0.007 uA
#         @q8[ic]     57.225 uA,     57.722 uA, delta      0.497 uA
#         @q8[ie]    -57.935 uA,    -58.439 uA, delta     -0.504 uA
#         @q9[ib]      0.652 uA,      1.062 uA, delta      0.410 uA
#         @q9[ic]     79.457 uA,    129.252 uA, delta     49.794 uA
#         @q9[ie]    -80.110 uA,   -130.313 uA, delta    -50.204 uA
#         @r10[i]     63.182 uA,     66.610 uA, delta      3.428 uA
#          @r1[i]     57.817 uA,     57.835 uA, delta      0.019 uA
#          @r2[i]    173.788 uA,    173.944 uA, delta      0.155 uA
#          @r3[i]     57.829 uA,     57.851 uA, delta      0.023 uA
#          @r4[i]    231.617 uA,    231.795 uA, delta      0.178 uA
#          @r5[i]     58.985 uA,     59.514 uA, delta      0.528 uA
#          @r7[i]     57.788 uA,     58.305 uA, delta      0.517 uA
#          @r8[i]     57.935 uA,     58.439 uA, delta      0.504 uA
#          @r9[i]     80.110 uA,    130.313 uA, delta     50.204 uA
#          @rb[i]   2505.881 uA,   8297.481 uA, delta   5791.600 uA
#          @rr[i]      1.918 uA,      1.920 uA, delta      0.002 uA
#         cathode   2494.119 mV,   2495.119 mV, delta      1.000 mV
#             mid   1057.733 mV,   1058.129 mV, delta      0.396 mV
#            q10b    631.820 mV,    666.099 mV, delta     34.279 mV
#             q1e   1817.437 mV,   1818.416 mV, delta      0.980 mV
#             q2b    640.641 mV,    640.665 mV, delta      0.023 mV
#             q4e   1176.203 mV,   1176.952 mV, delta      0.749 mV
#             q5b    641.368 mV,    641.599 mV, delta      0.231 mV
#             q5c    940.261 mV,    938.896 mV, delta     -1.365 mV
#             q6b    640.174 mV,    640.197 mV, delta      0.023 mV
#             q7b   1866.832 mV,   1867.187 mV, delta      0.356 mV
#             q7e   2447.888 mV,   2448.474 mV, delta      0.586 mV
#             q8e   2447.771 mV,   2448.368 mV, delta      0.597 mV
#             q9b   1292.621 mV,   1347.032 mV, delta     54.411 mV
#             q9e    643.836 mV,    685.646 mV, delta     41.809 mV
#              r1     46.253 mV,     46.268 mV, delta      0.015 mV
#             ref   2494.119 mV,   2495.119 mV, delta      1.000 mV
#       v1#branch  -2505.881 uA,  -8297.481 uA, delta  -5791.600 uA
#             vcc   5000.000 mV,  10792.600 mV, delta   5792.600 mV

# %%
ng.cmd('dc v1 3 15 100m')
# print(ng.vector_names())
vin = ng.vector('v-sweep')
vout = ng.vector('cathode')
I = -ng.vector('v1#branch')
fig, ax = plt.subplots()
plt.plot(vin, vout, label='Vout')
plt.xlabel('Vin')
plt.ylabel('Vout')
# plt.ylim(2.502, 2.51)
plt.ylim(2.493, 2.496)
plt.legend(loc="upper left")
ax2 = ax.twinx()
plt.plot(vin, I*1e3, 'orange', label='Id')
plt.ylabel("Id (mA)")
plt.legend(loc="lower right")
deltaV = vout[-1] - vout[0]
print("delta Vout = %.3f mV" % (1e3*deltaV))
deltaVin = vin[-1] - vin[0]
print("line regulation: %.3f %%" % (deltaV / deltaVin * 100))
# Out:
# delta Vout = 2.277 mV
# line regulation: 0.019 %
